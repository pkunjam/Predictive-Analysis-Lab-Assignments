# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv('drug2.csv')
df
# Out:
#       sex  dose  response
# 0       1   0.1     13.75
# 1       1   0.2     12.90
# 2       1   0.3     19.26
# 3       1   0.4     20.34
# 4       1   0.5     19.97
# 5       1   0.6     26.80
# 6       1   0.7     26.33
# 7       1   0.8     32.94
# 8       1   0.9     34.10
# 9       1   1.0     35.02
# 10      1   1.1     39.74
# 11      1   1.2     42.40
# 12      1   1.3     45.09
# 13      1   1.4     43.83
# 14      1   1.5     46.72
# 15      1   1.6     55.23
# 16      1   1.7     58.81
# 17      1   1.8     58.53
# 18      1   1.9     59.09
# 19      1   2.0     63.70
# 20      1   2.1     67.42
# 21      1   2.2     68.30
# 22      1   2.3     74.78
# 23      1   2.4     79.89
# 24      1   2.5     77.95
# 25      1   2.6     82.89
# 26      1   2.7     82.06
# 27      1   2.8     82.27
# 28      1   2.9     90.81
# 29      1   3.0     94.28
# ...   ...   ...       ...
# 3170    0   7.1     29.00
# 3171    0   7.2     29.44
# 3172    0   7.3     24.18
# 3173    0   7.4     27.85
# 3174    0   7.5     23.21
# 3175    0   7.6     21.89
# 3176    0   7.7     26.95
# 3177    0   7.8     29.93
# 3178    0   7.9     27.51
# 3179    0   8.0     30.26
# 3180    0   8.1     28.52
# 3181    0   8.2     27.52
# 3182    0   8.3     29.05
# 3183    0   8.4     31.96
# 3184    0   8.5     30.76
# 3185    0   8.6     30.27
# 3186    0   8.7     34.41
# 3187    0   8.8     27.86
# 3188    0   8.9     26.82
# 3189    0   9.0     27.72
# 3190    0   9.1     31.71
# 3191    0   9.2     31.36
# 3192    0   9.3     29.96
# 3193    0   9.4     33.42
# 3194    0   9.5     33.34
# 3195    0   9.6     36.33
# 3196    0   9.7     31.65
# 3197    0   9.8     33.35
# 3198    0   9.9     32.26
# 3199    0  10.0     36.09
#
# [3200 rows x 3 columns]

# %%
df_binary = df[['response','dose']]
X = np.array(df_binary['response']).reshape(-1,1)
y = np.array(df_binary['dose']).reshape(-1,1)

# %%
regr = LinearRegression()
regr.fit(X_train, y_train)
print(regr.score(X_test, y_test))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-d9b37c09cd1b> in <module>
#       1 regr = LinearRegression()
# ----> 2 regr.fit(X_train, y_train)
#       3 print(regr.score(X_test, y_test))
#
# NameError: name 'X_train' is not defined
